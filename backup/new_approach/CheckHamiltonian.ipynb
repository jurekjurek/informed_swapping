# %%
import numpy as np
import matplotlib.pyplot as plt
from Hamiltonian_controlled_sparsity import *
from scipy.sparse.linalg import eigsh

# %%
Ham = make_controlled_sparse_ground_state_hamiltonian_fast(4, 12, 0.9, 42)

# %%
plt.imshow(np.abs(Ham[0].toarray()))

# %%
w,v = eigsh(Ham[0], k=1, which='SA')
print(v)
# Out:
# [[-1.01922986e-01-5.07469756e-02j]
#  [ 1.93193034e-03-3.10250845e-01j]
#  [ 1.70573905e-01-7.44756213e-02j]
#  [ 2.28071356e-02+2.44254185e-01j]
#  [ 1.32756887e-01-5.93126984e-02j]
#  [ 2.74935797e-17-3.34535962e-19j]
#  [ 3.12123892e-02+2.74402125e-01j]
#  [ 6.06178679e-01-4.87443001e-02j]
#  [-1.05703196e-01-1.99755393e-02j]
#  [-1.42969697e-01+5.34017044e-03j]
#  [-2.58067636e-01+1.05401169e-01j]
#  [ 2.51837658e-01-2.56754245e-01j]
#  [ 1.09776897e-16+1.12192302e-16j]
#  [-5.47235666e-17-5.49412838e-17j]
#  [-6.59923652e-19+1.48032336e-19j]
#  [ 2.70204150e-01+1.28873877e-01j]]
